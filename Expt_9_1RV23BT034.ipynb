# %% [markdown]
# <a href="https://colab.research.google.com/github/louismathewbt23/Bioinformatics/blob/main/Expt_9_1RV23BT034.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file_path = '/content/NMGSE8CE016-Alignment.txt'

print(f"Reading the first 20 lines of: {file_path}\n")
with open(file_path, 'r') as f:
    for i, line in enumerate(f):
        if i >= 20:
            break
        print(line.strip())

print("\nSuccessfully read the first 20 lines of the file.")
# Out:
# Reading the first 20 lines of: /content/NMGSE8CE016-Alignment.txt
#
# RID: NMGSE8CE016
# Job Title:P05067:RecName: Full=Amyloid-beta precursor...
# Program: BLASTP
# Database: ClusteredNR clustered nr
# Query #1: RecName: Full=Amyloid-beta precursor protein; Short=APP; AltName: Full=ABPP; AltName: Full=APPI; AltName: Full=Alzheimer disease amyloid A4 protein homolog; AltName: Full=Alzheimer disease amyloid protein; AltName: Full=Amyloid precursor protein; AltName: Full=Amyloid-beta (A4) precursor protein; AltName: Full=Amyloid-beta A4 protein; AltName: Full=Cerebral vascular amyloid peptide; Short=CVAP; AltName: Full=PreA4; AltName: Full=Protease nexin-II; Short=PN-II; Contains: RecName: Full=N-APP; Contains: RecName: Full=Soluble APP-alpha; Short=S-APP-alpha; Contains: RecName: Full=Soluble APP-beta; Short=S-APP-beta; Contains: RecName: Full=C99; AltName: Full=Beta-secretase C-terminal fragment; Short=Beta-CTF; Contains: RecName: Full=Amyloid-beta protein 42; Short=Abeta42; AltName: Full=Beta-APP42; Contains: RecName: Full=Amyloid-beta protein 40; Short=Abeta40; AltName: Full=Beta-APP40; Contains: RecName: Full=C83; AltName: Full=Alpha-secretase C-terminal fragment; Short=Alpha-CTF; Contains: RecName: Full=P3(42); Contains: RecName: Full=P3(40); Contains: RecName: Full=C80; Contains: RecName: Full=Gamma-secretase C-terminal fragment 59; AltName: Full=Amyloid intracellular domain 59; Short=AICD-59; Short=AID(59); AltName: Full=Gamma-CTF(59); Contains: RecName: Full=Gamma-secretase C-terminal fragment 57; AltName: Full=Amyloid intracellular domain 57; Short=AICD-57; Short=AID(57); AltName: Full=Gamma-CTF(57); Contains: RecName: Full=Gamma-secretase C-terminal fragment 50; AltName: Full=Amyloid intracellular domain 50; Short=AICD-50; Short=AID(50); AltName: Full=Gamma-CTF(50); Contains: RecName: Full=C31; Flags: Precursor Query ID: sp|P05067.3 Length: 770
#
# Clusters producing significant alignments:
# #          #          Scientific      Cluster                    Max    Total Query   E   Per.   Acc.
# Cluster Rep.                                                      Mem.       Taxa       Name            Ancestor        Taxid      Score  Score cover Value Ident  Len        Accession
# amyloid-beta precursor protein isoform X1 [Mustela lutreola]      13         4          Mustelidae      weasel, mink... 9655       1573   1573  100%  0.0   97.40  957        XP_059020505.1
# amyloid-beta precursor protein isoform APP-770 precursor [Cani... 15         12         Boreoeutheria   placentals      1437010    1564   1564  100%  0.0   96.88  770        NP_001006601.2
# amyloid-beta precursor protein isoform 1 precursor [Mus musculus] 843        288        Tetrapoda       tetrapods       32523      1551   1551  100%  0.0   96.62  770        NP_001185752.1
# amyloid-beta precursor protein isoform X1 [Mustela erminea]       7          1          Mustela erminea ermine          36723      1544   1544  99%   0.0   96.99  941        XP_032209113.1
# PREDICTED: amyloid beta A4 protein [Condylura cristata]           1          1          Condylura cr... star-nosed mole 143302     1419   1419  91%   0.0   97.28  872        XP_012586147.1
# hypothetical protein [Bos mutus]                                  2          2          Laurasiatheria  placentals      314145     1405   1405  98%   0.0   89.76  783        MXQ95533.1
# amyloid-beta A4 protein isoform X3 [Prionailurus iriomotensis]    1          1          Prionailurus... Iriomote cat    37030      1328   1328  98%   0.0   91.67  776        GAB5576331.1
# PREDICTED: amyloid beta A4 protein isoform X2 [Gekko japonicus]   4          3          Sauria          diapsids        32561      1321   1321  100%  0.0   86.03  733        XP_015279692.1
# amyloid-beta precursor protein precursor [Gallus gallus]          298        211        Archelosauria   vertebrates     1329799    1317   1317  100%  0.0   91.04  751        NP_989639.2
# amyloid-beta precursor protein isoform X2 [Heteronotia binoei]    4          3          Sauria          diapsids        32561      1301   1301  100%  0.0   85.34  732        XP_060090360.1
# amyloid-beta precursor protein isoform X2 [Rhineura floridana]    40         37         Amniota         amniotes        32524      1300   1300  100%  0.0   85.90  734        XP_061483863.1
#
# Successfully read the first 20 lines of the file.

# %%
file_path = '/content/NMGSE8CE016-Alignment.txt'

print(f"Reading lines 21 to 120 of: {file_path}\n")
with open(file_path, 'r') as f:
    for i, line in enumerate(f):
        if 20 <= i < 120:
            print(line.strip())
        elif i >= 120:
            break

print("\nSuccessfully read lines 21 to 120 of the file.")
# Out:
# Reading lines 21 to 120 of: /content/NMGSE8CE016-Alignment.txt
#
# amyloid-beta precursor protein isoform X2 [Candoia aspera]        17         14         Amniota         amniotes        32524      1298   1298  100%  0.0   84.00  733        XP_063161529.1
# amyloid-beta precursor protein isoform X2 [Lacerta agilis]        1          1          Lacerta agilis  Sand lizard     80427      1298   1298  100%  0.0   85.90  734        XP_033002772.1
# amyloid-beta precursor protein isoform X2 [Podarcis muralis]      1          1          Podarcis mur... Common wall ... 64176      1298   1298  100%  0.0   85.90  734        XP_028582808.1
# amyloid-beta precursor protein isoform X2 [Podarcis raffonei]     1          1          Podarcis raf... Aeolian wall... 65483      1297   1297  100%  0.0   85.77  734        XP_053242515.1
# amyloid-beta precursor protein isoform X2 [Zootoca vivipara]      1          1          Zootoca vivi... common lizard   8524       1295   1295  100%  0.0   85.77  734        XP_034970741.1
# amyloid-beta precursor protein isoform X2 [Varanus komodoensis]   1          1          Varanus komo... Komodo dragon   61221      1293   1293  100%  0.0   85.68  736        XP_044297862.1
# amyloid-beta precursor protein isoform X6 [Manis javanica]        1          1          Manis javanica  Malayan pang... 9974       1292   1292  83%   0.0   96.39  696        XP_073087944.1
# amyloid-beta precursor protein isoform X1 [Ahaetulla prasina]     1          1          Ahaetulla pr... snakes          499056     1290   1290  100%  0.0   84.99  734        XP_058042729.1
# amyloid-beta precursor protein isoform X2 [Elgaria multicarina... 2          1          Elgaria mult... lizards & sn... 159646     1288   1288  99%   0.0   86.11  737        XP_062982811.1
#
#
# Alignments:
#
# >amyloid-beta precursor protein isoform X1 [Mustela lutreola]
# Sequence ID: XP_059020505.1 Length: 957
# Range 1: 188 to 957
#
# Score:1573 bits(4074), Expect:0.0,
# Method:Compositional matrix adjust.,
# Identities:750/770(97%), Positives:760/770(98%), Gaps:0/770(0%)
#
# Successfully read lines 21 to 120 of the file.

# %%
import re

file_path = '/content/NMGSE8CE016-Alignment.txt'

# Read the entire file content
with open(file_path, 'r') as f:
    full_content = f.read()

# Split the content into lines
lines = full_content.splitlines()

# Initialize lists to store extracted information
protein_names = set()
alternative_names = set()
gene_names = set()
organism_info = set()
descriptive_info = []

# Keywords to look for in descriptions for domains/pathways/functions
functional_keywords = [
    "Amyloid-beta", "APP", "precursor protein", "membrane-bound",
    "protease inhibitor", "neurogenesis", "cell adhesion", "apoptosis",
    "protein processing", "proteolysis", "signal transduction",
    "growth factor", "receptor", "extracellular domain", "transmembrane domain",
    "intracellular domain", "Kunitz-type", "heparin-binding", "beta-secretase",
    "alpha-secretase", "gamma-secretase", "amyloidogenic", "non-amyloidogenic"
]

# Iterate through the lines to extract information
current_protein_block = False
for line_num, line in enumerate(lines):
    line = line.strip()

    # Identify lines describing a significant hit, especially the target protein
    if line.startswith('>SP:') and "Amyloid-beta precursor protein" in line:
        current_protein_block = True
        # Extract full name and alternative name if present
        parts = line.split(' ', 2) # Split into identifier, short name, and rest
        if len(parts) > 2:
            full_description = parts[2]
            # Full name
            name_match = re.search(r'(.*?)(?: OS=|$)', full_description)
            if name_match: # Extract everything before 'OS=' or end of line
                protein_names.add(name_match.group(1).strip())

            # Alternative names (often indicated by things like '(Fragment)')
            if "(Fragment)" in full_description:
                alternative_names.add(full_description)

            # Organism information
            os_match = re.search(r'OS=(.*?)(?: OX=|$)', full_description)
            if os_match: # Extract everything after 'OS=' and before 'OX=' or end of line
                organism_info.add(os_match.group(1).strip())


    elif line.startswith('GN=') and current_protein_block:
        # Extract gene name
        gene_name_match = re.search(r'GN=(\w+)', line)
        if gene_name_match:
            gene_names.add(gene_name_match.group(1))

    # Check for general descriptive/functional information in lines following the hit description
    # This part is heuristic and might need refinement based on exact file structure
    elif current_protein_block and (line.startswith('Score =') or line.startswith('Length=') or line.startswith('Identities =')):
        # End of the specific protein description block for annotation extraction
        current_protein_block = False

    # Look for functional keywords in any line for broader context, especially after the initial hits table
    # This is a general scan, not tied to a specific protein block as much as the above.
    # Avoid collecting blast alignment lines as descriptive info.
    if not line.startswith(('Query', 'Sbjct', 'Score', 'Identities', 'Length')):
        for keyword in functional_keywords:
            if keyword.lower() in line.lower() and line not in descriptive_info and line.strip():
                descriptive_info.append(line)
                break # Add the line once if any keyword matches

# Print the extracted information
print("\n--- Extracted Functional Annotations ---")
print("Full Protein Names:")
for name in sorted(list(protein_names)):
    print(f"- {name}")

print("\nAlternative Names (from descriptions):")
if alternative_names:
    for name in sorted(list(alternative_names)):
        print(f"- {name}")
else:
    print("- None explicitly found in descriptions")

print("\nGene Names:")
if gene_names:
    for gn in sorted(list(gene_names)):
        print(f"- {gn}")
else:
    print("- None explicitly found")

print("\nOrganism Information:")
if organism_info:
    for org in sorted(list(organism_info)):
        print(f"- {org}")
else:
    print("- None explicitly found")

print("\nOther Relevant Descriptive Information (containing functional keywords):")
if descriptive_info:
    # Filter out duplicate and non-descriptive lines (like just 'Length=')
    unique_descriptive_info = []
    seen_lines = set()
    for info_line in descriptive_info:
        if info_line not in seen_lines:
            unique_descriptive_info.append(info_line)
            seen_lines.add(info_line)
    for info in unique_descriptive_info:
        print(f"- {info}")
else:
    print("- No additional descriptive information found using general keywords.")
# Out:
# --- Extracted Functional Annotations ---
# Full Protein Names:
#
# Alternative Names (from descriptions):
# - None explicitly found in descriptions
#
# Gene Names:
# - None explicitly found
#
# Organism Information:
# - None explicitly found
#
# Other Relevant Descriptive Information (containing functional keywords):
# - Job Title:P05067:RecName: Full=Amyloid-beta precursor...
# - amyloid-beta precursor protein isoform X1 [Mustela lutreola]      13         4          Mustelidae      weasel, mink... 9655       1573   1573  100%  0.0   97.40  957        XP_059020505.1
# - amyloid-beta precursor protein isoform APP-770 precursor [Cani... 15         12         Boreoeutheria   placentals      1437010    1564   1564  100%  0.0   96.88  770        NP_001006601.2
# - amyloid-beta precursor protein isoform 1 precursor [Mus musculus] 843        288        Tetrapoda       tetrapods       32523      1551   1551  100%  0.0   96.62  770        NP_001185752.1
# - amyloid-beta precursor protein isoform X1 [Mustela erminea]       7          1          Mustela erminea ermine          36723      1544   1544  99%   0.0   96.99  941        XP_032209113.1
# - amyloid-beta A4 protein isoform X3 [Prionailurus iriomotensis]    1          1          Prionailurus... Iriomote cat    37030      1328   1328  98%   0.0   91.67  776        GAB5576331.1
# - amyloid-beta precursor protein precursor [Gallus gallus]          298        211        Archelosauria   vertebrates     1329799    1317   1317  100%  0.0   91.04  751        NP_989639.2
# - amyloid-beta precursor protein isoform X2 [Heteronotia binoei]    4          3          Sauria          diapsids        32561      1301   1301  100%  0.0   85.34  732        XP_060090360.1
# - amyloid-beta precursor protein isoform X2 [Rhineura floridana]    40         37         Amniota         amniotes        32524      1300   1300  100%  0.0   85.90  734        XP_061483863.1
# - amyloid-beta precursor protein isoform X2 [Candoia aspera]        17         14         Amniota         amniotes        32524      1298   1298  100%  0.0   84.00  733        XP_063161529.1
# - amyloid-beta precursor protein isoform X2 [Lacerta agilis]        1          1          Lacerta agilis  Sand lizard     80427      1298   1298  100%  0.0   85.90  734        XP_033002772.1
# - amyloid-beta precursor protein isoform X2 [Podarcis muralis]      1          1          Podarcis mur... Common wall ... 64176      1298   1298  100%  0.0   85.90  734        XP_028582808.1
# - amyloid-beta precursor protein isoform X2 [Podarcis raffonei]     1          1          Podarcis raf... Aeolian wall... 65483      1297   1297  100%  0.0   85.77  734        XP_053242515.1
# - amyloid-beta precursor protein isoform X2 [Zootoca vivipara]      1          1          Zootoca vivi... common lizard   8524       1295   1295  100%  0.0   85.77  734        XP_034970741.1
# - amyloid-beta precursor protein isoform X2 [Varanus komodoensis]   1          1          Varanus komo... Komodo dragon   61221      1293   1293  100%  0.0   85.68  736        XP_044297862.1
# - amyloid-beta precursor protein isoform X4 [Dendrobates...         1          1          Dendrobates ... dyeing poiso... 92724      1129   1129  95%   0.0   82.04  707        XP_073440617.1
# - amyloid beta (A4) precursor protein (peptidase nexin-II,...       1          1          Homo sapiens    human           9606       1128   1128  73%   0.0   96.44  563        EAX09957.1
# - amyloid-beta precursor protein isoform X2 [Protopterus annectens] 3          1          Protopterus ... West African... 7888       1125   1125  100%  0.0   75.39  731        XP_043927289.1
# - amyloid beta (A4) precursor protein a isoform X1 [Callorhinchu... 7          3          Chondrichthyes  cartilaginou... 7777       1123   1123  95%   0.0   75.65  689        XP_007901746.1
# - amyloid-beta precursor protein isoform X4 [Amblyraja radiata]     19         7          Batoidea        rays            117893     1120   1120  98%   0.0   76.42  736        XP_032888282.1
# - Amyloid-beta precursor protein [Bufotes viridis]                  3          1          Bufotes viridis European gre... 30338      1113   1113  96%   0.0   77.67  707        CAN1984402.1
# - amyloid-beta protein [Homo sapiens]                               1          1          Homo sapiens    human           9606       1112   1112  70%   0.0   99.07  547        AAB59501.1
# - amyloid-beta A4 protein, partial [Chelydra serpentina]            1          1          Chelydra ser... Common snapp... 8475       1099   1099  84%   0.0   90.05  636        KAG6934511.1
# - amyloid-beta precursor protein isoform X8 [Chamaea fasciata]      1          1          Chamaea fasc... birds           190680     1088   1088  83%   0.0   88.85  642        XP_066064756.1
# - amyloid-beta A4 protein-like isoform X3 [Conger conger]           11         6          Elopomorpha     ray-finned f... 32521      1082   1082  99%   0.0   70.11  756        XP_061083234.1
# - amyloid-beta precursor protein isoform X2 [Podarcis lilfordi]     1          1          Podarcis lil... Lilford's wa... 74358      1075   1075  83%   0.0   86.54  622        CAI5772688.1
# - amyloid beta (A4) precursor protein b isoform X1 [Chanos chanos]  3          1          Chanos chanos   milkfish        29144      1071   1071  99%   0.0   69.55  763        XP_030641643.1
# - amyloid beta (A4) precursor protein a isoform X1 [Salminus...     4          4          Characiphysae   ray-finned f... 186628     1071   1071  100%  0.0   70.34  765        XP_072513959.1
# - amyloid-beta A4 protein isoform X2 [Lepisosteus oculatus]         3          1          Lepisosteus ... spotted gar     7918       1069   1069  99%   0.0   70.93  731        XP_069053927.1
# - amyloid-beta precursor protein [Grus japonensis]                  1          1          Grus japonensis Red-crowned ... 30415      1067   1067  83%   0.0   89.81  638        GAB0178113.1
# - amyloid-beta A4 protein-like isoform X3 [Scyliorhinus canicula]   2          1          Scyliorhinus... smaller spot... 7830       1063   1063  92%   0.0   74.48  695        XP_038657334.1
# - amyloid beta (A4) precursor protein a isoform X1 [Osmerus mordax] 4          2          Osmeridae       smelts          8012       1048   1048  99%   0.0   70.78  766        XP_067116120.1
# - amyloid beta (A4) precursor protein a isoform X1 [Hemibagrus...   25         18         Characiphysae   ray-finned f... 186628     1045   1045  99%   0.0   68.41  759        XP_058237197.1
# - Amyloid-beta A4 protein, partial [Spheniscus mendiculus]          3          3          Archosauria     vertebrates     8492       1036   1036  80%   0.0   89.81  620        KAF1452923.1
# - amyloid beta (A4) precursor protein b isoform X1 [Hoplias...      3          2          Characoidei     ray-finned f... 1489739    1032   1032  99%   0.0   67.47  759        XP_066542111.1
# - RecName: Full=Amyloid-beta A4 protein; AltName: Full=ABPP;...     1          1          Dichotomycte... green puffer... 2593188    1028   1028  99%   0.0   66.29  780        O73683.1
# - amyloid beta (A4) precursor protein a precursor [Danio rerio]     48         31         Cypriniformes   carps and ot... 7952       1022   1022  99%   0.0   69.09  738        NP_571639.1
# - amyloid-beta precursor protein isoform X1 [Podarcis lilfordi]     1          1          Podarcis lil... Lilford's wa... 74358      1020   1020  78%   0.0   86.73  586        CAI5772689.1
# - LOW QUALITY PROTEIN: amyloid-beta A4 protein-like [Perca...       10         8          Percomorphaceae ray-finned f... 1489872    1013   1013  98%   0.0   65.26  762        XP_039673691.1
# - amyloid-beta A4 protein-like isoform X1 [Salarias fasciatus]      3          2          Salariinae      bony fishes     703913     1008   1008  98%   0.0   64.81  813        XP_029943729.1
# - amyloid-beta A4 protein-like isoform X1 [Leuresthes tenuis]       4          4          Euacanthomor... ray-finned f... 123369     1004   1004  98%   0.0   66.45  754        XP_072252879.1
# - amyloid beta (A4) precursor protein a isoform X1 [Nothobranchi... 1          1          Nothobranchi... turquoise ki... 105023     1004   1004  98%   0.0   67.30  769        XP_015808081.1
# - amyloid-beta A4 protein-like isoform X1 [Nelusetta ayraudi]       2          2          Euacanthomor... ray-finned f... 123369     1003   1003  98%   0.0   66.06  759        XP_075870677.1
# - amyloid beta (A4) precursor protein b isoform X1 [Gouania...      1          1          Gouania will... blunt-snoute... 441366     1000   1000  98%   0.0   66.71  742        XP_028291365.1
# - amyloid beta (A4) precursor protein b isoform X1 [Genypterus...   1          1          Genypterus b... pink cusk-eel   154954     999    999   98%   0.0   66.02  759        XP_076015249.1
# - amyloid-beta A4 protein-like isoform X1 [Myxocyprinus asiaticus]  48         32         Cypriniformes   carps and ot... 7952       997    997   99%   0.0   65.13  753        XP_051567048.1
# - amyloid beta (A4) precursor protein b isoform X1 [Denticeps...    3          1          Denticeps cl... denticle her... 299321     997    997   98%   0.0   67.22  772        XP_028846102.1
# - amyloid beta (A4) precursor protein b isoform X2 [Limanda...      51         45         Acanthomorphata ray-finned f... 123368     995    995   98%   0.0   67.32  747        XP_060943977.1
# - amyloid-beta A4 protein-like isoform X2 [Notolabrus celidotus]    5          4          Percomorphaceae ray-finned f... 1489872    994    994   95%   0.0   67.96  711        XP_034550156.1
# - amyloid beta (A4) precursor protein b isoform X1 [Hippoglossus... 3          1          Hippoglossus... Atlantic hal... 8267       994    994   98%   0.0   65.72  761        XP_034431098.1
# - >amyloid-beta precursor protein isoform X1 [Mustela lutreola]
# - >amyloid-beta precursor protein isoform APP-770 precursor [Canis lupus familiaris]
# - >amyloid-beta precursor protein isoform 1 precursor [Mus musculus]
# - >amyloid-beta precursor protein isoform X1 [Mustela erminea]
# - >amyloid-beta A4 protein isoform X3 [Prionailurus iriomotensis]
# - >amyloid-beta precursor protein precursor [Gallus gallus]
# - >amyloid-beta precursor protein isoform X2 [Heteronotia binoei]
# - >amyloid-beta precursor protein isoform X2 [Rhineura floridana]
# - >amyloid-beta precursor protein isoform X2 [Candoia aspera]
# - >amyloid-beta precursor protein isoform X2 [Lacerta agilis]
# - >amyloid-beta precursor protein isoform X2 [Podarcis muralis]
# - >amyloid-beta precursor protein isoform X2 [Podarcis raffonei]
# - >amyloid-beta precursor protein isoform X2 [Zootoca vivipara]
# - >amyloid-beta precursor protein isoform X2 [Varanus komodoensis]
# - >amyloid-beta precursor protein isoform X6 [Manis javanica]
# - >amyloid-beta precursor protein isoform X1 [Ahaetulla prasina]
# - >amyloid-beta precursor protein isoform X2 [Elgaria multicarinata webbii]
# - >amyloid-beta precursor protein isoform X3 [Rhineura floridana]
# - >amyloid beta precursor protein [Phyllostomus discolor]
# - >LOW QUALITY PROTEIN: amyloid-beta precursor protein [Thamnophis elegans]
# - >amyloid beta (A4) precursor protein a isoform X1 [Latimeria chalumnae]
# - >amyloid-beta precursor protein isoform X2 [Monodelphis domestica]
# - >amyloid-beta precursor protein isoform X2 [Ambystoma mexicanum]
# - >amyloid-beta precursor protein isoform 1-T1 [Discoglossus pictus]
# - >amyloid-beta A4 protein-like isoform X2 [Scyliorhinus canicula]
# - >amyloid-beta precursor protein precursor [Xenopus tropicalis]
# - >amyloid-beta precursor protein isoform X2 [Geotrypetes seraphini]
# - >amyloid-beta precursor protein isoform X1 [Hyperolius riggenbachi]
# - >Amyloid-beta A4 protein [Varanus komodoensis]
# - >amyloid-beta precursor protein isoform X2 [Ahaetulla prasina]
# - >amyloid-beta A4 protein-like [Huso huso]
# - >amyloid-beta precursor protein isoform X2 [Mus musculus]
# - >amyloid-beta precursor protein isoform X7 [Mus caroli]
# - >amyloid-beta precursor protein isoform X4 [Dendrobates tinctorius]
# - >amyloid beta (A4) precursor protein (peptidase nexin-II, Alzheimer disease), isoform CRA_a, partial [Homo sapiens]
# - >amyloid-beta precursor protein isoform X2 [Protopterus annectens]
# - >amyloid beta (A4) precursor protein a isoform X1 [Callorhinchus milii]
# - >amyloid-beta precursor protein isoform X4 [Amblyraja radiata]
# - >Amyloid-beta precursor protein [Bufotes viridis]
# - >amyloid-beta protein [Homo sapiens]
# - >amyloid-beta A4 protein, partial [Chelydra serpentina]
# - >amyloid-beta precursor protein isoform X8 [Chamaea fasciata]
# - >amyloid-beta A4 protein-like isoform X3 [Conger conger]
# - >amyloid-beta precursor protein isoform X2 [Podarcis lilfordi]
# - >amyloid beta (A4) precursor protein b isoform X1 [Chanos chanos]
# - >amyloid beta (A4) precursor protein a isoform X1 [Salminus brasiliensis]
# - >amyloid-beta A4 protein isoform X2 [Lepisosteus oculatus]
# - >amyloid-beta precursor protein [Grus japonensis]
# - >amyloid-beta A4 protein-like isoform X3 [Scyliorhinus canicula]
# - >amyloid beta (A4) precursor protein a isoform X1 [Osmerus mordax]
# - >amyloid beta (A4) precursor protein a isoform X1 [Hemibagrus wyckioides]
# - >Amyloid-beta A4 protein, partial [Spheniscus mendiculus]
# - >amyloid beta (A4) precursor protein b isoform X1 [Hoplias malabaricus]
# - >RecName: Full=Amyloid-beta A4 protein; AltName: Full=ABPP; Short=APP; AltName: Full=Alzheimer disease amyloid A4 protein homolog; AltName: Full=Amyloid precursor protein; AltName: Full=Amyloid-beta precursor protein; Contains: RecName: Full=Amyloid-beta protein; AltName: Full=A-beta; AltName: Full=APP-beta; Flags: Precursor [Dichotomyctere fluviatilis]
# - >amyloid beta (A4) precursor protein a precursor [Danio rerio]
# - >amyloid-beta precursor protein isoform X1 [Podarcis lilfordi]
# - >LOW QUALITY PROTEIN: amyloid-beta A4 protein-like [Perca fluviatilis]
# - >amyloid-beta A4 protein-like isoform X1 [Salarias fasciatus]
# - >amyloid-beta A4 protein-like isoform X1 [Leuresthes tenuis]
# - >amyloid beta (A4) precursor protein a isoform X1 [Nothobranchius furzeri]
# - >amyloid-beta A4 protein-like isoform X1 [Nelusetta ayraudi]
# - >amyloid beta (A4) precursor protein b isoform X1 [Gouania willdenowi]
# - >amyloid beta (A4) precursor protein b isoform X1 [Genypterus blacodes]
# - >amyloid-beta A4 protein-like isoform X1 [Myxocyprinus asiaticus]
# - >amyloid beta (A4) precursor protein b isoform X1 [Denticeps clupeoides]
# - >amyloid beta (A4) precursor protein b isoform X2 [Limanda limanda]
# - >amyloid-beta A4 protein-like isoform X2 [Notolabrus celidotus]
# - >amyloid beta (A4) precursor protein b isoform X1 [Hippoglossus hippoglossus]

# %%
structured_annotations = {}

# 2. Add 'Protein Names' and 'Gene Names'
structured_annotations['Protein Names'] = sorted(list(protein_names))
structured_annotations['Gene Names'] = sorted(list(gene_names))

# 3. Identify and add 'Domains'
structured_annotations['Domains'] = ['Kunitz-type protease inhibitor domains']

# 4. Identify and add 'Biological Processes'
structured_annotations['Biological Processes'] = [
    'neurogenesis', 'cell adhesion', 'apoptosis', 'protein processing',
    'signal transduction', 'growth factor receptor activity'
]

# 5. Identify and add 'Associated Pathways'
structured_annotations['Associated Pathways'] = [
    'amyloidogenic processing', 'non-amyloidogenic processing',
    'Amyloid-beta peptide generation'
]

# 6. Add 'Organism Information'
structured_annotations['Organism Information'] = sorted(list(organism_info))

# 7. Print the structured_annotations dictionary
import json
print(json.dumps(structured_annotations, indent=4))
# Out:
# {
#     "Protein Names": [],
#     "Gene Names": [],
#     "Domains": [
#         "Kunitz-type protease inhibitor domains"
#     ],
#     "Biological Processes": [
#         "neurogenesis",
#         "cell adhesion",
#         "apoptosis",
#         "protein processing",
#         "signal transduction",
#         "growth factor receptor activity"
#     ],
#     "Associated Pathways": [
#         "amyloidogenic processing",
#         "non-amyloidogenic processing",
#         "Amyloid-beta peptide generation"
#     ],
#     "Organism Information": []
# }

# %%
import graphviz

# Initialize a directed graph object
dot = graphviz.Digraph(comment='Amyloid-beta Precursor Protein Functional Annotations', format='png')
dot.attr(rankdir='LR', size='10,10')

# 3. Create a central node for the main protein
dot.node('APP_MAIN', 'Amyloid-beta Precursor Protein (APP)', shape='box', style='filled', fillcolor='#ADD8E6') # Light blue

# Define colors for different categories
category_colors = {
    'Protein Names': '#90EE90', # Light green
    'Gene Names': '#FFD700',    # Gold
    'Domains': '#FFA07A',       # Light salmon
    'Biological Processes': '#BA55D3', # Medium orchid
    'Associated Pathways': '#4682B4',  # Steel blue
    'Organism Information': '#87CEEB' # Sky blue
}

# 4. For each category, create nodes and draw edges
for category, items in structured_annotations.items():
    if category == 'Organism Information': # Organism info can be too many, keep it separate or just a label
        continue # Skip organisms for direct linking to avoid clutter

    # Add a category node first
    dot.node(category.replace(' ', '_'), category, shape='octagon', style='filled', fillcolor='#D3D3D3') # Light gray
    dot.edge('APP_MAIN', category.replace(' ', '_'), label='has')

    for item in items:
        item_id = item.replace(' ', '_').replace('-', '_').replace('(', '').replace(')', '').replace('.', '') # Create a valid ID
        dot.node(item_id, item, shape='ellipse', style='filled', fillcolor=category_colors.get(category, '#FFFFFF'))
        dot.edge(category.replace(' ', '_'), item_id)

# Add Organism Information as a separate cluster or legend if too many
# For simplicity, let's just connect the main APP node to a summary organism node
organism_summary_id = 'Organisms_Summary'
dot.node(organism_summary_id, 'Organisms (Widespread Conservation)', shape='folder', style='filled', fillcolor=category_colors['Organism Information'])
dot.edge('APP_MAIN', organism_summary_id, label='found in')


# 5. Render the graph to a file
try:
    dot.render('app_functional_annotations', view=False, cleanup=True)
    print("Diagram 'app_functional_annotations.png' generated successfully.")
except Exception as e:
    print(f"Error rendering diagram: {e}")
# Out:
# Diagram 'app_functional_annotations.png' generated successfully.

# %%
import graphviz

# 1. Initialize a directed graph object focusing on Alzheimer's disease
dot_alz = graphviz.Digraph(comment='APP and Alzheimer\'s Disease Pathway', format='png')
dot_alz.attr(rankdir='LR', size='10,10')

# 2. Create nodes for the key components
# Main protein
dot_alz.node('APP', 'Amyloid-beta Precursor Protein (APP)', shape='box', style='filled', fillcolor='#ADD8E6') # Light blue

# Processes
dot_alz.node('AMY_PROC', 'Amyloidogenic Processing', shape='octagon', style='filled', fillcolor='#FFA07A') # Light salmon
dot_alz.node('AB_PEPTIDE', 'Amyloid-beta Peptide Generation', shape='ellipse', style='filled', fillcolor='#FFD700') # Gold

# Disease
dot_alz.node('ALZ_DIS', 'Alzheimer\'s Disease', shape='box', style='filled', fillcolor='#DC143C', fontcolor='white') # Crimson

# 3. Establish edges to show the relationships
dot_alz.edge('APP', 'AMY_PROC', label='undergoes')
dot_alz.edge('AMY_PROC', 'AB_PEPTIDE', label='leads to')
dot_alz.edge('AB_PEPTIDE', 'ALZ_DIS', label='contributes to')

# 4. Customize edges for clarity (optional, but good for emphasis)
dot_alz.edge('AMY_PROC', 'AB_PEPTIDE', arrowhead='vee', color='darkgreen', penwidth='1.5')
dot_alz.edge('AB_PEPTIDE', 'ALZ_DIS', arrowhead='vee', color='darkred', penwidth='2.0', label='key factor in')


# 5. Render the graph to a PNG file
try:
    dot_alz.render('app_alzheimers_pathway', view=False, cleanup=True)
    print("Diagram 'app_alzheimers_pathway.png' generated successfully.")
except Exception as e:
    print(f"Error rendering diagram: {e}")
# Out:
# Diagram 'app_alzheimers_pathway.png' generated successfully.
